# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_minke = '/home/jupyter-n.mekkes@gmail.com-f6d87/clinical_history/input_data/training_data_relabel_minke.xlsx'
path_megan = '/home/jupyter-n.mekkes@gmail.com-f6d87/clinical_history/input_data/training_data_relabel_megan.xlsx'

# %%
minke = pd.read_excel(path_minke, engine='openpyxl', index_col=[0])
megan = pd.read_excel(path_megan, engine='openpyxl', index_col=[1])
# megan.columns

# %%
## for minke, convert to 0-1 df
minke.fillna(0, inplace=True)
minke.replace('X', 1, inplace=True)

## for megan, only relevant column
megan = megan.drop(['Unnamed: 0','sum_true','sentence_length'], axis=1, errors='ignore')

## we start with the first 1000 rows
megan = megan.head(n=1000)
minke = minke.head(n=1000)

## calculate means
counts_minke = minke.iloc[:,2:].sum()
counts_megan = megan.iloc[:,2:].sum()

## modify the column names so we know which columns belong to who
clinical_attributes = minke.columns[2:].tolist()
minke.columns = minke.columns[:2].tolist() + [col + '_minke' for col in minke.columns[2:]]
megan.columns = megan.columns[:2].tolist() + [col + '_megan' for col in megan.columns[2:]]

print(minke.shape)
print(megan.shape)
print(clinical_attributes)
display(minke.head())
# Out:
# (1000, 92)
# (1000, 92)
# ['Muscular_Weakness', 'Spasticity', 'Hyperreflexia_and_oth_reflexes', 'Frontal_release_signs', 'Fasciculations', 'Positive_sensory_symptoms', 'Negative_sensory_symptoms', 'Parkinsonism', 'Facial_masking', 'Tremor', 'Bradykinesia', 'Rigidity', 'Vertigo', 'Nystagmus', 'Ataxia', 'Loss_of_coordination', 'Balance_problems', 'Frequent_falls', 'Decreased_motor_skills', 'Unspecified_disturbed_gait_patt', 'Mobility_problems', 'Dementia', 'Cognitive_decline', 'Bradyphrenia', 'Lack_of_insight', 'Facade_behavior', 'Head_turning_sign', 'Memory_impairment', 'Amnesia', 'Forgetfulness', 'Imprinting_disturbances', 'Impaired_recognition', 'Confabulations', 'Disorientation', 'Wandering', 'Confusion', 'Aphasia', 'Word_finding_problems', 'Language_impairment', 'Impaired_comprehension', 'Communication_problems', 'Dysarthria', 'Apraxia', 'Executive_function_disorder', 'Lack_of_planning_organis_overv', 'Concentration_problems', 'Disinhibition', 'Loss_of_decorum', 'Apathy_inertia', 'Lack_of_initiative', 'Loss_of_sympathy_empathy', 'Compulsive_behavior', 'Hyperorality', 'Changed_moods_emotions', 'Changed_behavior_personality', 'Agitation', 'Aggressive_behavior', 'Stress', 'Anxiety', 'Depressed_mood', 'Suicidal_ideation', 'Mania', 'Psychosis', 'Psychiatric_admissions', 'Paranoia_suspiciousness', 'Hallucinations', 'Delusions', 'Delirium', 'Day_night_rhythm_disturbances', 'Sleep_disturbances', 'Restlessness', 'Vivid_dreaming', 'Hearing_problems', 'Visual_problems', 'Olfactory_gustatory_dysfunction', 'Urinary_incontinence', 'Urinary_problems_other', 'Constipation', 'Swallowing_problems_Dysphagia', 'Seizures', 'Orthostatic_hypotension', 'Headache_migraine', 'Fatigue', 'Declined_deteriorated_health', 'Cachexia', 'Weight_loss', 'Reduces_oral_intake', 'Help_in_ADL', 'Day_care', 'Admission_to_nursing_home']
#               Year_Sentence_nr  \
# NBB_nr
# NBB 2007-003   2002_sentence_1
# NBB 2011-024   2011_sentence_8
# NBB 1999-052   1996_sentence_8
# NBB 2011-061  2009_sentence_19
# NBB 2011-061  2009_sentence_22
#
#                                                       Sentence  \
# NBB_nr
# NBB 2007-003             Patient was referred to a neurologist
# NBB 2011-024  Her condition deteriorated with fast progression
# NBB 1999-052          Treatment with a vitamine B12 injections
# NBB 2011-061       In May patient was diagnosed with scoliosis
# NBB 2011-061     In September excessive salivation was present
#
#               Muscular_Weakness_minke  Spasticity_minke  \
# NBB_nr
# NBB 2007-003                        0                 0
# NBB 2011-024                        0                 0
# NBB 1999-052                        0                 0
# NBB 2011-061                        0                 0
# NBB 2011-061                        0                 0
#
#               Hyperreflexia_and_oth_reflexes_minke  \
# NBB_nr
# NBB 2007-003                                     0
# NBB 2011-024                                     0
# NBB 1999-052                                     0
# NBB 2011-061                                     0
# NBB 2011-061                                     0
#
#               Frontal_release_signs_minke  Fasciculations_minke  \
# NBB_nr
# NBB 2007-003                            0                   0.0
# NBB 2011-024                            0                   0.0
# NBB 1999-052                            0                   0.0
# NBB 2011-061                            0                   0.0
# NBB 2011-061                            0                   0.0
#
#               Positive_sensory_symptoms_minke  \
# NBB_nr
# NBB 2007-003                                0
# NBB 2011-024                                0
# NBB 1999-052                                0
# NBB 2011-061                                0
# NBB 2011-061                                0
#
#               Negative_sensory_symptoms_minke  Parkinsonism_minke  ...  \
# NBB_nr                                                             ...
# NBB 2007-003                                0                   0  ...
# NBB 2011-024                                0                   0  ...
# NBB 1999-052                                0                   0  ...
# NBB 2011-061                                0                   0  ...
# NBB 2011-061                                0                   0  ...
#
#               Orthostatic_hypotension_minke  Headache_migraine_minke  \
# NBB_nr
# NBB 2007-003                            0.0                        0
# NBB 2011-024                            0.0                        0
# NBB 1999-052                            0.0                        0
# NBB 2011-061                            0.0                        0
# NBB 2011-061                            0.0                        0
#
#               Fatigue_minke  Declined_deteriorated_health_minke  \
# NBB_nr
# NBB 2007-003              0                                   0
# NBB 2011-024              0                                   1
# NBB 1999-052              0                                   0
# NBB 2011-061              0                                   0
# NBB 2011-061              0                                   0
#
#               Cachexia_minke  Weight_loss_minke  Reduces_oral_intake_minke  \
# NBB_nr
# NBB 2007-003               0                  0                          0
# NBB 2011-024               0                  0                          0
# NBB 1999-052               0                  0                          0
# NBB 2011-061               0                  0                          0
# NBB 2011-061               0                  0                          0
#
#               Help_in_ADL_minke  Day_care_minke  \
# NBB_nr
# NBB 2007-003                  0               0
# NBB 2011-024                  0               0
# NBB 1999-052                  0               0
# NBB 2011-061                  0               0
# NBB 2011-061                  0               0
#
#               Admission_to_nursing_home_minke
# NBB_nr
# NBB 2007-003                                0
# NBB 2011-024                                0
# NBB 1999-052                                0
# NBB 2011-061                                0
# NBB 2011-061                                0
#
# [5 rows x 92 columns]

# %%
counts_minke
counts_megan

# # Calculate the mean between the two sums
mean_values = pd.concat([counts_minke, counts_megan]).groupby(level=0).mean()

print(mean_values)
# Out:
# Admission_to_nursing_home    10.5
# Aggressive_behavior           4.0
# Agitation                     7.0
# Amnesia                       2.0
# Anxiety                       7.5
#                              ...
# Visual_problems               6.0
# Vivid_dreaming                0.0
# Wandering                     4.0
# Weight_loss                   9.5
# Word_finding_problems         6.0
# Length: 90, dtype: float64

# %%
combined_df = pd.concat([megan, minke], axis=1)
# combined_df.head()

# %%
from sklearn.metrics import jaccard_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import pairwise_distances
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", category=DataConversionWarning)

def krippendorff_alpha(labels_minke, labels_megan):
    # Convert labels to a matrix with rows as coders and columns as instances
    labels_matrix = np.vstack((labels_minke, labels_megan))
    # Calculate pairwise distance matrix
    distance_matrix = pairwise_distances(labels_matrix, metric='jaccard')
    # Calculate observed disagreement
    observed_disagreement = np.mean(distance_matrix)
    # Calculate expected disagreement
    random_labels = np.random.randint(low=0, high=2, size=labels_matrix.shape)
    random_distance_matrix = pairwise_distances(random_labels, metric='jaccard')
    expected_disagreement = np.mean(random_distance_matrix)
    # display(labels_matrix)
    # display(labels_matrix.shape)
    # display(distance_matrix)
    # display(distance_matrix.shape)
    # display(observed_disagreement)
    # print('random labels')
    # display(random_labels)
    # display(expected_disagreement)
    # print('max')
    # display(np.max(labels_matrix))
    # Calculate Krippendorff's alpha
    alpha = 1 - (observed_disagreement / expected_disagreement)
    
    return alpha

jaccard_scores = {}
cohen_score = {}
krip = {}
# symptom_columns = combined_df.columns[3:]  # Exclude the sentence column

for symptom in clinical_attributes:
    # display(symptom)
    labels_minke = combined_df[symptom + '_minke']
    labels_megan = combined_df[symptom + '_megan']
    
    ## if a clinical attribute is not scored by either scores, it is not possible or meaningful to calculate IOS
    if (labels_minke.eq(0).all()) and (labels_megan.eq(0).all()):
        print(f"{symptom} is NOT labeled in the 1000 sentence by either Minke or Megan")
    else:
    
        ## ranges from 0(perfect disagreement) to 1 (perfect agreement)
        ## e.g. 10 sentences scored for 'tremor'. 6 are all scored as tremor by both labelers.
        ## 2 are scored as present by labeler A but not by B, and the last two sentences vice versa
        ## simple, 6 sentences out of 10 agree--> 6/10 = 0.6
        jaccard_similarity = jaccard_score(labels_minke, labels_megan, average='binary')
        jaccard_scores[symptom] = jaccard_similarity

        ## ranges from -1 to 1
        ## same example as above, P0 is 0.6
        ## then we calculate Pe:
        ## Pe = ((A notes symptom present) * (B notes symptom present)) + ((A notes absent)*(B notes absent))
        ## In this case, Pe = (((6/10)*(6/10))+((4/10)*(4/10))) = 0.52
        ## κ = (0.6 - 0.52) / (1 - 0.52) ≈ 0.1667
        kappa = cohen_kappa_score(labels_minke, labels_megan)
        cohen_score[symptom] = kappa
        
        alpha = krippendorff_alpha(labels_minke, labels_megan)
        krip[symptom] = alpha
        print(f"for {symptom}, the jaccard similarity is {jaccard_similarity} and cohens kappa is {kappa} and krip is {alpha}")
    

mean_jaccard_score = sum(jaccard_scores.values()) / len(jaccard_scores)
mean_cohen_score = sum(cohen_score.values()) / len(cohen_score)
mean_krip = sum(krip.values()) / len(krip)

print(jaccard_scores)
print(mean_cohen_score)
print(mean_jaccard_score)
print(mean_krip)
# Out:
# for Muscular_Weakness, the jaccard similarity is 0.875 and cohens kappa is 0.9323181049069373 and krip is 0.8152173913043479
# for Spasticity, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Hyperreflexia_and_oth_reflexes, the jaccard similarity is 0.75 and cohens kappa is 0.856156501726122 and krip is 0.6144957983193278
# for Frontal_release_signs, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# Fasciculations is NOT labeled in the 1000 sentence by either Minke or Megan
# for Positive_sensory_symptoms, the jaccard similarity is 0.4 and cohens kappa is 0.5702005730659025 and krip is 0.1218934911242604
# for Negative_sensory_symptoms, the jaccard similarity is 0.6 and cohens kappa is 0.7481108312342569 and krip is 0.3893004115226337
# for Parkinsonism, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Facial_masking, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Tremor, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Bradykinesia, the jaccard similarity is 0.4 and cohens kappa is 0.5686556434219986 and krip is 0.09819639278557113
# for Rigidity, the jaccard similarity is 0.8888888888888888 and cohens kappa is 0.9406739439962032 and krip is 0.8359893758300133
# for Vertigo, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Nystagmus, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Ataxia, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Loss_of_coordination, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Balance_problems, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Frequent_falls, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Decreased_motor_skills, the jaccard similarity is 0.0 and cohens kappa is -0.0010010010010010895 and krip is -0.4757281553398056
# Unspecified_disturbed_gait_patt is NOT labeled in the 1000 sentence by either Minke or Megan
# for Mobility_problems, the jaccard similarity is 0.8076923076923077 and cohens kappa is 0.8910675381263616 and krip is 0.7104072398190044
# for Dementia, the jaccard similarity is 0.9629629629629629 and cohens kappa is 0.9806186526087294 and krip is 0.9433819064966606
# for Cognitive_decline, the jaccard similarity is 0.7142857142857143 and cohens kappa is 0.8313090418353576 and krip is 0.5697478991596638
# for Bradyphrenia, the jaccard similarity is 0.5 and cohens kappa is 0.6657754010695187 and krip is 0.2422997946611909
# for Lack_of_insight, the jaccard similarity is 0.6666666666666666 and cohens kappa is 0.7990353697749196 and krip is 0.5059055118110236
# for Facade_behavior, the jaccard similarity is 0.5 and cohens kappa is 0.6662216288384513 and krip is 0.2665330661322646
# Head_turning_sign is NOT labeled in the 1000 sentence by either Minke or Megan
# for Memory_impairment, the jaccard similarity is 0.8518518518518519 and cohens kappa is 0.9179621805652406 and krip is 0.780763489016848
# for Amnesia, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Forgetfulness, the jaccard similarity is 0.6363636363636364 and cohens kappa is 0.7757847533632287 and krip is 0.46323795726186157
# for Imprinting_disturbances, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Impaired_recognition, the jaccard similarity is 0.75 and cohens kappa is 0.856651376146789 and krip is 0.6070686070686071
# for Confabulations, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Disorientation, the jaccard similarity is 0.9333333333333333 and cohens kappa is 0.9650104968509448 and krip is 0.9009485094850949
# for Wandering, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Confusion, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# Aphasia is NOT labeled in the 1000 sentence by either Minke or Megan
# for Word_finding_problems, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Language_impairment, the jaccard similarity is 0.5 and cohens kappa is 0.6653279785809907 and krip is 0.23023715415019763
# for Impaired_comprehension, the jaccard similarity is 0.3333333333333333 and cohens kappa is 0.4973190348525469 and krip is 0.006185567010309256
# for Communication_problems, the jaccard similarity is 0.5 and cohens kappa is 0.6662216288384513 and krip is 0.24850299401197595
# for Dysarthria, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Apraxia, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Executive_function_disorder, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Lack_of_planning_organis_overv, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Concentration_problems, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Disinhibition, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Loss_of_decorum, the jaccard similarity is 0.5714285714285714 and cohens kappa is 0.7242393602353157 and krip is 0.3549060542797495
# for Apathy_inertia, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# Lack_of_initiative is NOT labeled in the 1000 sentence by either Minke or Megan
# for Loss_of_sympathy_empathy, the jaccard similarity is 0.0 and cohens kappa is 0.0 and krip is -0.47105788423153694
# for Compulsive_behavior, the jaccard similarity is 0.875 and cohens kappa is 0.9328318108543794 and krip is 0.8147410358565736
# for Hyperorality, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Changed_moods_emotions, the jaccard similarity is 0.625 and cohens kappa is 0.7678018575851393 and krip is 0.45035282258064513
# for Changed_behavior_personality, the jaccard similarity is 0.4 and cohens kappa is 0.5673908863680062 and krip is 0.11190476190476195
# for Agitation, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Aggressive_behavior, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Stress, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Anxiety, the jaccard similarity is 0.6666666666666666 and cohens kappa is 0.798549556809025 and krip is 0.5134779750164367
# for Depressed_mood, the jaccard similarity is 0.8333333333333334 and cohens kappa is 0.9075785582255083 and krip is 0.7407786885245902
# for Suicidal_ideation, the jaccard similarity is 0.5 and cohens kappa is 0.6656636576395855 and krip is 0.246987951807229
# for Mania, the jaccard similarity is 0.5 and cohens kappa is 0.6662216288384513 and krip is 0.239
# for Psychosis, the jaccard similarity is 0.8 and cohens kappa is 0.8883928571428572 and krip is 0.6978131212723657
# for Psychiatric_admissions, the jaccard similarity is 0.42857142857142855 and cohens kappa is 0.5980707395498392 and krip is 0.1497695852534563
# Paranoia_suspiciousness is NOT labeled in the 1000 sentence by either Minke or Megan
# for Hallucinations, the jaccard similarity is 0.9090909090909091 and cohens kappa is 0.9518768046198267 and krip is 0.8617386589553587
# for Delusions, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Delirium, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Day_night_rhythm_disturbances, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Sleep_disturbances, the jaccard similarity is 0.5 and cohens kappa is 0.6657754010695187 and krip is 0.2670565302144249
# for Restlessness, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# Vivid_dreaming is NOT labeled in the 1000 sentence by either Minke or Megan
# for Hearing_problems, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Visual_problems, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# Olfactory_gustatory_dysfunction is NOT labeled in the 1000 sentence by either Minke or Megan
# for Urinary_incontinence, the jaccard similarity is 0.7142857142857143 and cohens kappa is 0.8313659359190556 and krip is 0.5829228243021347
# for Urinary_problems_other, the jaccard similarity is 0.5 and cohens kappa is 0.6641590542718968 and krip is 0.2612085769980508
# for Constipation, the jaccard similarity is 0.9090909090909091 and cohens kappa is 0.9518768046198267 and krip is 0.8582498582498582
# for Swallowing_problems_Dysphagia, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Seizures, the jaccard similarity is 0.8181818181818182 and cohens kappa is 0.898989898989899 and krip is 0.732
# Orthostatic_hypotension is NOT labeled in the 1000 sentence by either Minke or Megan
# for Headache_migraine, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Fatigue, the jaccard similarity is 0.6470588235294118 and cohens kappa is 0.7828132918265402 and krip is 0.4497153700189752
# for Declined_deteriorated_health, the jaccard similarity is 0.6875 and cohens kappa is 0.8123686580606424 and krip is 0.5209660297239915
# for Cachexia, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Weight_loss, the jaccard similarity is 0.7272727272727273 and cohens kappa is 0.8405951115834219 and krip is 0.6051405899603244
# for Reduces_oral_intake, the jaccard similarity is 0.5 and cohens kappa is 0.6648793565683646 and krip is 0.247
# for Help_in_ADL, the jaccard similarity is 0.4166666666666667 and cohens kappa is 0.5848161328588375 and krip is 0.10069444444444442
# for Day_care, the jaccard similarity is 1.0 and cohens kappa is 1.0 and krip is 1.0
# for Admission_to_nursing_home, the jaccard similarity is 0.9090909090909091 and cohens kappa is 0.9518768046198267 and krip is 0.8590909090909091
# {'Muscular_Weakness': 0.875, 'Spasticity': 1.0, 'Hyperreflexia_and_oth_reflexes': 0.75, 'Frontal_release_signs': 1.0, 'Positive_sensory_symptoms': 0.4, 'Negative_sensory_symptoms': 0.6, 'Parkinsonism': 1.0, 'Facial_masking': 1.0, 'Tremor': 1.0, 'Bradykinesia': 0.4, 'Rigidity': 0.8888888888888888, 'Vertigo': 1.0, 'Nystagmus': 1.0, 'Ataxia': 1.0, 'Loss_of_coordination': 1.0, 'Balance_problems': 1.0, 'Frequent_falls': 1.0, 'Decreased_motor_skills': 0.0, 'Mobility_problems': 0.8076923076923077, 'Dementia': 0.9629629629629629, 'Cognitive_decline': 0.7142857142857143, 'Bradyphrenia': 0.5, 'Lack_of_insight': 0.6666666666666666, 'Facade_behavior': 0.5, 'Memory_impairment': 0.8518518518518519, 'Amnesia': 1.0, 'Forgetfulness': 0.6363636363636364, 'Imprinting_disturbances': 1.0, 'Impaired_recognition': 0.75, 'Confabulations': 1.0, 'Disorientation': 0.9333333333333333, 'Wandering': 1.0, 'Confusion': 1.0, 'Word_finding_problems': 1.0, 'Language_impairment': 0.5, 'Impaired_comprehension': 0.3333333333333333, 'Communication_problems': 0.5, 'Dysarthria': 1.0, 'Apraxia': 1.0, 'Executive_function_disorder': 1.0, 'Lack_of_planning_organis_overv': 1.0, 'Concentration_problems': 1.0, 'Disinhibition': 1.0, 'Loss_of_decorum': 0.5714285714285714, 'Apathy_inertia': 1.0, 'Loss_of_sympathy_empathy': 0.0, 'Compulsive_behavior': 0.875, 'Hyperorality': 1.0, 'Changed_moods_emotions': 0.625, 'Changed_behavior_personality': 0.4, 'Agitation': 1.0, 'Aggressive_behavior': 1.0, 'Stress': 1.0, 'Anxiety': 0.6666666666666666, 'Depressed_mood': 0.8333333333333334, 'Suicidal_ideation': 0.5, 'Mania': 0.5, 'Psychosis': 0.8, 'Psychiatric_admissions': 0.42857142857142855, 'Hallucinations': 0.9090909090909091, 'Delusions': 1.0, 'Delirium': 1.0, 'Day_night_rhythm_disturbances': 1.0, 'Sleep_disturbances': 0.5, 'Restlessness': 1.0, 'Hearing_problems': 1.0, 'Visual_problems': 1.0, 'Urinary_incontinence': 0.7142857142857143, 'Urinary_problems_other': 0.5, 'Constipation': 0.9090909090909091, 'Swallowing_problems_Dysphagia': 1.0, 'Seizures': 0.8181818181818182, 'Headache_migraine': 1.0, 'Fatigue': 0.6470588235294118, 'Declined_deteriorated_health': 0.6875, 'Cachexia': 1.0, 'Weight_loss': 0.7272727272727273, 'Reduces_oral_intake': 0.5, 'Help_in_ADL': 0.4166666666666667, 'Day_care': 1.0, 'Admission_to_nursing_home': 0.9090909090909091}
# 0.8631056030500953
# 0.8025755206492314
# 0.7045560778500469

# %%
# Convert the dictionary to a DataFrame
data_jaccard = pd.DataFrame.from_dict(jaccard_scores, orient='index', columns=['Jaccard'])
data_krip = pd.DataFrame.from_dict(krip, orient='index', columns=['Krippendorf Alpha'])
data_cohen = pd.DataFrame.from_dict(cohen_score, orient='index', columns=["Cohen's Kappa"])

# Merge the DataFrames
data = pd.concat([data_jaccard, data_krip, data_cohen], axis=1)
data = data.sort_values(by=["Cohen's Kappa"],ascending=False)

# Rotate the plot by 90 degrees
plt.figure(figsize=(8, 20))

# Create the scatter plot
sns.scatterplot(data=data, y=data.index, x='Jaccard', label='Jaccard', alpha=0.5)
sns.scatterplot(data=data, y=data.index, x='Krippendorf Alpha', label='Krippendorf Alpha', alpha=0.5)
sns.scatterplot(data=data, y=data.index, x="Cohen's Kappa", label="Cohen's Kappa",alpha=0.5)

# Add legend
plt.legend()
# Set x-axis label
plt.xlabel('Performance')
# Add mean values as text
for symptom, mean_value in mean_values.items():
    if symptom in jaccard_scores.keys():
        # print(symptom)
        plt.text(1.20, data.index.get_loc(symptom), f'{mean_value:.1f}', ha='center', va='center')

# Show the plot
# plt.show()
plt.savefig('inter_operator.pdf', dpi=300,bbox_inches='tight')

# %%
# Convert the data to long format
data_long = data.melt(var_name='Metric', value_name='Value', ignore_index=False).reset_index()

# Define the number of rows and columns for subplots
num_rows = len(data.index) // 3  # Divide by 3 for 3 columns
num_cols = 3

# Calculate the figure size based on the number of subplots
fig_height = 3 * num_rows
fig_width = 12  # Increase the width for 3 columns

# Create the figure and subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(fig_width, fig_height), sharex=True)

# Flatten the axes array
axes = axes.flatten()

# Loop through each symptom and create the bar plots
for i, symptom in enumerate(data.index):
    # Get the data for the current symptom
    symptom_data = data_long[data_long['index'] == symptom]

    # Set the subplot title as the symptom name
    axes[i].set_title(symptom)

    # Create the bar plot
    sns.barplot(data=symptom_data, x='Metric', y='Value', hue='Metric', palette='pastel', ax=axes[i])
    
    # Remove legend for each subplot
    axes[i].get_legend().remove()

    # Remove y-axis labels for all subplots except the first one in each row
    if i % num_cols != 0:
        axes[i].set_ylabel('')

    # Set y-axis label for the first subplot in each row
    if i % num_cols == 0:
        axes[i].set_ylabel('Value')

    # Set x-axis label for the last row of subplots
    if i >= num_cols * (num_rows - 1):
        axes[i].set_xlabel('Metric')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()
